# %%
# 부산 구 별 범죄 발생 횟수
import pandas as pd
df_02 = pd.read_csv('/Users/dabeen/Desktop/K-DigitalTraining/Project/Machine_Learning/New_Project/2016_2020(3)_encoded.csv')
df_02
# Out:
#       시점  발생지별(1)  발생지별(2) 범죄발생 총건수(A) (건) 형법범 (건) 형법범 (건).1 형법범 (건).2
# 0     시점  발생지별(1)  발생지별(2)              소계      소계  강력범죄(흉악)  강력범죄(폭력)
# 1   2016       부산       소계          143080   76213      2019     17123
# 2   2016       부산       중구            5535    3354        83       737
# 3   2016       부산       서구            4724    2560        59       556
# 4   2016       부산       동구            5931    3303        85       731
# ..   ...      ...      ...             ...     ...       ...       ...
# 81  2020       부산       강서            8128    2956        57       472
# 82  2020       부산       연제            9581    7195       134      1107
# 83  2020       부산       수영            6190    3397       117       801
# 84  2020       부산       사상            9062    6354       169      1221
# 85  2020       부산      기장군            6917    3438        71       664
#
# [86 rows x 7 columns]

# %%
# 행 드랍
df_02.drop([0], inplace=True)
df_02
# Out:
#       시점 발생지별(1) 발생지별(2) 범죄발생 총건수(A) (건) 형법범 (건) 형법범 (건).1 형법범 (건).2
# 1   2016      부산      소계          143080   76213      2019     17123
# 2   2016      부산      중구            5535    3354        83       737
# 3   2016      부산      서구            4724    2560        59       556
# 4   2016      부산      동구            5931    3303        85       731
# 5   2016      부산      영도            7313    2561        92       601
# ..   ...     ...     ...             ...     ...       ...       ...
# 81  2020      부산      강서            8128    2956        57       472
# 82  2020      부산      연제            9581    7195       134      1107
# 83  2020      부산      수영            6190    3397       117       801
# 84  2020      부산      사상            9062    6354       169      1221
# 85  2020      부산     기장군            6917    3438        71       664
#
# [85 rows x 7 columns]

# %%
# 행 드랍(2)
df_02 = df_02[df_02['발생지별(2)'] != '소계']
df_02
# Out:
#       시점 발생지별(1) 발생지별(2) 범죄발생 총건수(A) (건) 형법범 (건) 형법범 (건).1 형법범 (건).2
# 2   2016      부산      중구            5535    3354        83       737
# 3   2016      부산      서구            4724    2560        59       556
# 4   2016      부산      동구            5931    3303        85       731
# 5   2016      부산      영도            7313    2561        92       601
# 6   2016      부산     부산진           19465   11725       391      2768
# ..   ...     ...     ...             ...     ...       ...       ...
# 81  2020      부산      강서            8128    2956        57       472
# 82  2020      부산      연제            9581    7195       134      1107
# 83  2020      부산      수영            6190    3397       117       801
# 84  2020      부산      사상            9062    6354       169      1221
# 85  2020      부산     기장군            6917    3438        71       664
#
# [80 rows x 7 columns]

# %%
# 열 드랍
df_02.drop(['발생지별(1)', '형법범 (건)'], axis=1, inplace=True)
df_02
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       시점 발생지별(2) 범죄발생 총건수(A) (건) 형법범 (건).1 형법범 (건).2
# 2   2016      중구            5535        83       737
# 3   2016      서구            4724        59       556
# 4   2016      동구            5931        85       731
# 5   2016      영도            7313        92       601
# 6   2016     부산진           19465       391      2768
# ..   ...     ...             ...       ...       ...
# 81  2020      강서            8128        57       472
# 82  2020      연제            9581       134      1107
# 83  2020      수영            6190       117       801
# 84  2020      사상            9062       169      1221
# ...

# %%
# 순서대로 정렬
df_02.sort_values(by=['발생지별(2)', '시점'], inplace=True)
df_02
# Out:
# <ipython-input-68-35e61595c5bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_02.sort_values(by=['발생지별(2)', '시점'], inplace=True)
#       시점 발생지별(2) 범죄발생 총건수(A) (건) 형법범 (건).1 형법범 (건).2
# 13  2016      강서            5589        45       372
# 30  2017      강서            6604        46       393
# 47  2018      강서            5986        63       440
# 64  2019      강서            6820        63       433
# 81  2020      강서            8128        57       472
# ..   ...     ...             ...       ...       ...
# 10  2016     해운대           15666       222      1753
# 27  2017     해운대           13345       264      1810
# 44  2018     해운대           13743       263      1688
# 61  2019     해운대           14386       267      1732
# 78  2020     해운대           11837       257      1388
#
# ...

# %%
# 컬럼명 변경
df_02.rename(columns={'발생지별(2)' : '위치', '범죄발생 총건수(A) (건)' : '범죄발생 총건수', '형법범 (건).1' : '강력범죄(흉악)', '형법범 (건).2' : '강력범죄(폭력)'}, inplace=True)
df_02
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       시점   위치 범죄발생 총건수 강력범죄(흉악) 강력범죄(폭력)
# 13  2016   강서     5589       45      372
# 30  2017   강서     6604       46      393
# 47  2018   강서     5986       63      440
# 64  2019   강서     6820       63      433
# 81  2020   강서     8128       57      472
# ..   ...  ...      ...      ...      ...
# 10  2016  해운대    15666      222     1753
# 27  2017  해운대    13345      264     1810
# 44  2018  해운대    13743      263     1688
# 61  2019  해운대    14386      267     1732
# 78  2020  해운대    11837      257     1388
#
# [80 rows x 5 columns]

# %%
df_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 13 to 78
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        80 non-null     object
#  1   위치        80 non-null     object
#  2   범죄발생 총건수  80 non-null     object
#  3   강력범죄(흉악)  80 non-null     object
#  4   강력범죄(폭력)  80 non-null     object
# dtypes: object(5)
# memory usage: 3.8+ KB

# %%
# object -> int
df_02['시점'] = df_02['시점'].astype(str).astype(int)
df_02['범죄발생 총건수'] = df_02['범죄발생 총건수'].astype(str).astype(int)
df_02['강력범죄(흉악)'] = df_02['강력범죄(흉악)'].astype(str).astype(int)
df_02['강력범죄(폭력)'] = df_02['강력범죄(폭력)'].astype(str).astype(int)
df_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 13 to 78
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        80 non-null     int64
#  1   위치        80 non-null     object
#  2   범죄발생 총건수  80 non-null     int64
#  3   강력범죄(흉악)  80 non-null     int64
#  4   강력범죄(폭력)  80 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 3.8+ KB
# <ipython-input-90-acccf10390ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_02['범죄발생 총건수'] = df_02['범죄발생 총건수'].astype(str).astype(int)
# <ipython-input-90-acccf10390ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_02.to_excel('01.xlsx', index=False, encoding='utf8')

# %%
# 년도별 분류
df_02_2016 = df_02[df_02['시점'] == 2016]
df_02_2016
# Out:
#       시점   위치  범죄발생 총건수  강력범죄(흉악)  강력범죄(폭력)
# 13  2016   강서      5589        45       372
# 12  2016   금정      8659       112       955
# 17  2016  기장군      5248        70       552
# 8   2016   남구     10008       111      1068
# 4   2016   동구      5931        85       731
# 7   2016   동래      9811       137      1212
# 6   2016  부산진     19465       391      2768
# 9   2016   북구      8033       132      1296
# 16  2016   사상      9550       151      1191
# 11  2016   사하     10693       123      1364
# 3   2016   서구      4724        59       556
# 15  2016   수영      7608        98       846
# 14  2016   연제      9243       108      1121
# 5   2016   영도      7313        92       601
# 2   2016   중구      5535        83       737
# 10  2016  해운대     15666       222      1753

# %%
# 년도별 분류 & 저장
df_02_2016.to_excel('01_2016.xlsx', index=False, encoding='utf8')

df_02_2017 = df_02[df_02['시점'] == 2017]
df_02_2017.to_excel('01_2017.xlsx', index=False, encoding='utf8')

df_02_2018 = df_02[df_02['시점'] == 2018]
df_02_2018.to_excel('01_2018.xlsx', index=False, encoding='utf8')

df_02_2019 = df_02[df_02['시점'] == 2019]
df_02_2019.to_excel('01_2019.xlsx', index=False, encoding='utf8')

df_02_2020 = df_02[df_02['시점'] == 2020]
df_02_2020.to_excel('01_2020.xlsx', index=False, encoding='utf8')

df_02_2020
# Out:
#       시점   위치  범죄발생 총건수  강력범죄(흉악)  강력범죄(폭력)
# 81  2020   강서      8128        57       472
# 80  2020   금정      6953       121       752
# 85  2020  기장군      6917        71       664
# 76  2020   남구      9642       128       985
# 72  2020   동구      5295        70       688
# 75  2020   동래      8118       146      1049
# 74  2020  부산진     16274       416      2547
# 77  2020   북구      8593       119      1143
# 84  2020   사상      9062       169      1221
# 79  2020   사하      8687       147      1168
# 71  2020   서구      3551        41       479
# 83  2020   수영      6190       117       801
# 82  2020   연제      9581       134      1107
# 73  2020   영도      3991        41       503
# 70  2020   중구      4094        68       540
# 78  2020  해운대     11837       257      1388

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# 예시용 그래프 

sns.set_theme(style="white", context="talk")
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

sns.barplot(df_02_2016['위치'], df_02_2016['범죄발생 총건수'], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Total crime")

sns.barplot(df_02_2016['위치'], df_02_2016['강력범죄(흉악)'], palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Heinous crime")

sns.barplot(df_02_2016['위치'], df_02_2016['강력범죄(폭력)'], palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Violent crime")

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

plt.show()
plt.savefig('Location_Crime.jpg')
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# 년도별 분류
df_02_2017 = df_02[df_02['시점'] == 2017]
df_02_2017
# Out:
#       시점   위치  범죄발생 총건수  강력범죄(흉악)  강력범죄(폭력)
# 30  2017   강서      6604        46       393
# 29  2017   금정      7114       140       846
# 34  2017  기장군      4959        64       614
# 25  2017   남구      8683       181      1027
# 21  2017   동구      5795        98       764
# 24  2017   동래      8821       169      1163
# 23  2017  부산진     17504       459      2805
# 26  2017   북구      7247       136      1194
# 33  2017   사상      9275       200      1161
# 28  2017   사하      9798       192      1370
# 20  2017   서구      4565        65       542
# 32  2017   수영      5839       140       924
# 31  2017   연제      7924       163      1030
# 22  2017   영도      4469        72       572
# 19  2017   중구      5360        99       705
# 27  2017  해운대     13345       264      1810

# %%
# 예시용 그래프

sns.set_theme(style="white", context="talk")
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

sns.barplot(df_02_2017['위치'], df_02_2017['범죄발생 총건수'], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Total crime")

sns.barplot(df_02_2017['위치'], df_02_2017['강력범죄(흉악)'], palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Heinous crime")

sns.barplot(df_02_2017['위치'], df_02_2017['강력범죄(폭력)'], palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Violent crime")

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

plt.show()
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df_02_2018 = df_02[df_02['시점'] == 2018]
df_02_2018

sns.set_theme(style="white", context="talk")
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

sns.barplot(df_02_2018['위치'], df_02_2018['범죄발생 총건수'], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Total crime")

sns.barplot(df_02_2018['위치'], df_02_2018['강력범죄(흉악)'], palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Heinous crime")

sns.barplot(df_02_2018['위치'], df_02_2018['강력범죄(폭력)'], palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Violent crime")

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

plt.show()
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df_02_2019 = df_02[df_02['시점'] == 2019]
df_02_2019

sns.set_theme(style="white", context="talk")
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

sns.barplot(df_02_2019['위치'], df_02_2019['범죄발생 총건수'], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Total crime")

sns.barplot(df_02_2019['위치'], df_02_2019['강력범죄(흉악)'], palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Heinous crime")

sns.barplot(df_02_2019['위치'], df_02_2019['강력범죄(폭력)'], palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Violent crime")

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

plt.show()
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df_02_2020 = df_02[df_02['시점'] == 2020]
df_02_2020

sns.set_theme(style="white", context="talk")
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

sns.barplot(df_02_2020['위치'], df_02_2020['범죄발생 총건수'], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Total crime")

sns.barplot(df_02_2020['위치'], df_02_2020['강력범죄(흉악)'], palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Heinous crime")

sns.barplot(df_02_2020['위치'], df_02_2020['강력범죄(폭력)'], palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Violent crime")

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

plt.show()
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df_02.to_csv('01_fin.csv', index=False)

# %%
# 범죄별 재범발생
df_05 = pd.read_csv('/Users/dabeen/Desktop/K-DigitalTraining/Project/Machine_Learning/New_Project/재범기간.csv', encoding='cp949')
df_05
# Out:
#       시점  범죄별(1)    범죄별(2)      합계    동종재범 동종재범.1 동종재범.2 동종재범.3 동종재범.4 동종재범.5  \
# 0     시점  범죄별(1)    범죄별(2)      소계      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내
# 1   2016      합계        소계  889429  277430  12294  17608  19166  61991  33770
# 2   2016     형법범        소계  453763  128149   8548  10895  10721  33695  15826
# 3   2016     형법범  강력범죄(흉악)   16653    1778     69    111    122    411    290
# 4   2016     형법범  강력범죄(폭력)  160076   43922   1492   2845   3133   9574   6136
# 5   2017      합계        소계  803710  250467  10598  15776  17898  56414  30340
# 6   2017     형법범        소계  425866  121924   7791  10576  10545  32337  15295
# 7   2017     형법범  강력범죄(흉악)   17216    2189     97    147    150    475    349
# 8   2017     형법범  강력범죄(폭력)  148678   42060   1463   2866   3098   9371   5797
# 9   2018      합계        소계  718529  222759  10074  14065  15584  49470  28444
# 10  2018     형법범        소계  409671  121128   8122  10652  10738  31921  15789
# ...

# %%
# 동종재범만 추출
df_05_01 = df_05.drop(['이종재범', '이종재범.1', '이종재범.2', '이종재범.3', '이종재범.4', '이종재범.5', '이종재범.6', '이종재범.7'], axis=1)
df_05_01
# Out:
#       시점  범죄별(1)    범죄별(2)      합계    동종재범 동종재범.1 동종재범.2 동종재범.3 동종재범.4 동종재범.5  \
# 0     시점  범죄별(1)    범죄별(2)      소계      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내
# 1   2016      합계        소계  889429  277430  12294  17608  19166  61991  33770
# 2   2016     형법범        소계  453763  128149   8548  10895  10721  33695  15826
# 3   2016     형법범  강력범죄(흉악)   16653    1778     69    111    122    411    290
# 4   2016     형법범  강력범죄(폭력)  160076   43922   1492   2845   3133   9574   6136
# 5   2017      합계        소계  803710  250467  10598  15776  17898  56414  30340
# 6   2017     형법범        소계  425866  121924   7791  10576  10545  32337  15295
# 7   2017     형법범  강력범죄(흉악)   17216    2189     97    147    150    475    349
# 8   2017     형법범  강력범죄(폭력)  148678   42060   1463   2866   3098   9371   5797
# 9   2018      합계        소계  718529  222759  10074  14065  15584  49470  28444
# 10  2018     형법범        소계  409671  121128   8122  10652  10738  31921  15789
# ...

# %%
# 열 드랍
df_05_01.drop(['범죄별(1)'], axis=1, inplace=True)
df_05_01
# Out:
#       시점    범죄별(2)      합계    동종재범 동종재범.1 동종재범.2 동종재범.3 동종재범.4 동종재범.5 동종재범.6  \
# 0     시점    범죄별(2)      소계      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내
# 1   2016        소계  889429  277430  12294  17608  19166  61991  33770  33147
# 2   2016        소계  453763  128149   8548  10895  10721  33695  15826  15415
# 3   2016  강력범죄(흉악)   16653    1778     69    111    122    411    290    286
# 4   2016  강력범죄(폭력)  160076   43922   1492   2845   3133   9574   6136   5690
# 5   2017        소계  803710  250467  10598  15776  17898  56414  30340  30125
# 6   2017        소계  425866  121924   7791  10576  10545  32337  15295  14800
# 7   2017  강력범죄(흉악)   17216    2189     97    147    150    475    349    304
# 8   2017  강력범죄(폭력)  148678   42060   1463   2866   3098   9371   5797   5345
# 9   2018        소계  718529  222759  10074  14065  15584  49470  28444  27397
# 10  2018        소계  409671  121128   8122  10652  10738  31921  15789  14862
# ...

# %%
# 컬럼명 변경
df_05_01.rename(columns={'범죄별(2)': '범죄별', '동종재범' : '소계', '동종재범.1' : '1개월이내', '동종재범.2':'3개월이내', '동종재범.3':'6개월이내', '동종재범.4':'1년이내', '동종재범.5':'2년이내', '동종재범.6':'3년이내', '동종재범.7':'3년초과'}, inplace=True)
df_05_01
# Out:
#       시점       범죄별      합계      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내  \
# 0     시점    범죄별(2)      소계      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내
# 1   2016        소계  889429  277430  12294  17608  19166  61991  33770  33147
# 2   2016        소계  453763  128149   8548  10895  10721  33695  15826  15415
# 3   2016  강력범죄(흉악)   16653    1778     69    111    122    411    290    286
# 4   2016  강력범죄(폭력)  160076   43922   1492   2845   3133   9574   6136   5690
# 5   2017        소계  803710  250467  10598  15776  17898  56414  30340  30125
# 6   2017        소계  425866  121924   7791  10576  10545  32337  15295  14800
# 7   2017  강력범죄(흉악)   17216    2189     97    147    150    475    349    304
# 8   2017  강력범죄(폭력)  148678   42060   1463   2866   3098   9371   5797   5345
# 9   2018        소계  718529  222759  10074  14065  15584  49470  28444  27397
# 10  2018        소계  409671  121128   8122  10652  10738  31921  15789  14862
# ...

# %%
# 불필요한 행 드랍
df_05_01.drop([0, 1, 5, 9, 13, 17], inplace=True)
df_05_01
# Out:
#       시점       범죄별      합계      소계 1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내  \
# 2   2016        소계  453763  128149  8548  10895  10721  33695  15826  15415
# 3   2016  강력범죄(흉악)   16653    1778    69    111    122    411    290    286
# 4   2016  강력범죄(폭력)  160076   43922  1492   2845   3133   9574   6136   5690
# 6   2017        소계  425866  121924  7791  10576  10545  32337  15295  14800
# 7   2017  강력범죄(흉악)   17216    2189    97    147    150    475    349    304
# 8   2017  강력범죄(폭력)  148678   42060  1463   2866   3098   9371   5797   5345
# 10  2018        소계  409671  121128  8122  10652  10738  31921  15789  14862
# 11  2018  강력범죄(흉악)   16471    2593   141    185    182    581    428    376
# 12  2018  강력범죄(폭력)  138887   40987  1482   2753   3142   8894   5923   5305
# 14  2019        소계  422216  124541  8299  10765  10680  33665  16123  15558
# 15  2019  강력범죄(흉악)   16479    2689   118    174    181    661    387    398
# ...

# %%
df_05_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 2 to 20
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      15 non-null     object
#  1   범죄별     15 non-null     object
#  2   합계      15 non-null     object
#  3   소계      15 non-null     object
#  4   1개월이내   15 non-null     object
#  5   3개월이내   15 non-null     object
#  6   6개월이내   15 non-null     object
#  7   1년이내    15 non-null     object
#  8   2년이내    15 non-null     object
#  9   3년이내    15 non-null     object
#  10  3년초과    15 non-null     object
# dtypes: object(11)
# memory usage: 1.4+ KB

# %%
# object -> int
df_05_01['시점'] = df_05_01['시점'].astype(str).astype(int)
df_05_01['합계'] = df_05_01['합계'].astype(str).astype(int)
df_05_01['소계'] = df_05_01['소계'].astype(str).astype(int)
df_05_01['1개월이내'] = df_05_01['1개월이내'].astype(str).astype(int)
df_05_01['3개월이내'] = df_05_01['3개월이내'].astype(str).astype(int)
df_05_01['6개월이내'] = df_05_01['6개월이내'].astype(str).astype(int)
df_05_01['1년이내'] = df_05_01['1년이내'].astype(str).astype(int)
df_05_01['2년이내'] = df_05_01['2년이내'].astype(str).astype(int)
df_05_01['3년이내'] = df_05_01['3년이내'].astype(str).astype(int)
df_05_01['3년초과'] = df_05_01['3년초과'].astype(str).astype(int)



df_05_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 2 to 20
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      15 non-null     int64
#  1   범죄별     15 non-null     object
#  2   합계      15 non-null     int64
#  3   소계      15 non-null     int64
#  4   1개월이내   15 non-null     int64
#  5   3개월이내   15 non-null     int64
#  6   6개월이내   15 non-null     int64
#  7   1년이내    15 non-null     int64
#  8   2년이내    15 non-null     int64
#  9   3년이내    15 non-null     int64
#  10  3년초과    15 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 1.4+ KB

# %%
df_05_01.drop(['합계'], axis=1, inplace=True)
df_05_01
# Out:
#       시점       범죄별      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내   3년초과
# 2   2016        소계  128149   8548  10895  10721  33695  15826  15415  33049
# 3   2016  강력범죄(흉악)    1778     69    111    122    411    290    286    489
# 4   2016  강력범죄(폭력)   43922   1492   2845   3133   9574   6136   5690  15052
# 6   2017        소계  121924   7791  10576  10545  32337  15295  14800  30580
# 7   2017  강력범죄(흉악)    2189     97    147    150    475    349    304    667
# 8   2017  강력범죄(폭력)   42060   1463   2866   3098   9371   5797   5345  14120
# 10  2018        소계  121128   8122  10652  10738  31921  15789  14862  29044
# 11  2018  강력범죄(흉악)    2593    141    185    182    581    428    376    700
# 12  2018  강력범죄(폭력)   40987   1482   2753   3142   8894   5923   5305  13488
# 14  2019        소계  124541   8299  10765  10680  33665  16123  15558  29451
# 15  2019  강력범죄(흉악)    2689    118    174    181    661    387    398    770
# ...

# %%
# save
df_05_01.to_excel('02_01_same.xlsx', index=False, encoding='utf8')
df_05_02.to_excel('02_02_diff.xlsx', index=False, encoding='utf8')

# %%
df_05_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 2 to 20
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      15 non-null     int64
#  1   범죄별     15 non-null     object
#  2   소계      15 non-null     int64
#  3   1개월이내   15 non-null     int64
#  4   3개월이내   15 non-null     int64
#  5   6개월이내   15 non-null     int64
#  6   1년이내    15 non-null     int64
#  7   2년이내    15 non-null     int64
#  8   3년이내    15 non-null     int64
#  9   3년초과    15 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 1.3+ KB

# %%
# 연도별 분류 & 저장

df_05_01_2016 = df_05_01[df_05_01['시점'] == 2016]
df_05_01_2017 = df_05_01[df_05_01['시점'] == 2017]
df_05_01_2018 = df_05_01[df_05_01['시점'] == 2018]
df_05_01_2019 = df_05_01[df_05_01['시점'] == 2019]
df_05_01_2020 = df_05_01[df_05_01['시점'] == 2020]

df_05_02_2016 = df_05_01[df_05_02['시점'] == 2016]
df_05_02_2017 = df_05_01[df_05_02['시점'] == 2017]
df_05_02_2018 = df_05_01[df_05_02['시점'] == 2018]
df_05_02_2019 = df_05_01[df_05_02['시점'] == 2019]
df_05_02_2020 = df_05_01[df_05_02['시점'] == 2020]


df_05_01_2016.to_excel('02_01_2016.xlsx', index=False, encoding='utf8')
df_05_01_2017.to_excel('02_01_2017.xlsx', index=False, encoding='utf8')
df_05_01_2018.to_excel('02_01_2018.xlsx', index=False, encoding='utf8')
df_05_01_2019.to_excel('02_01_2019.xlsx', index=False, encoding='utf8')
df_05_01_2020.to_excel('02_01_2020.xlsx', index=False, encoding='utf8')

df_05_02_2016.to_excel('02_02_2016.xlsx', index=False, encoding='utf8')
df_05_02_2017.to_excel('02_02_2017.xlsx', index=False, encoding='utf8')
df_05_02_2018.to_excel('02_02_2018.xlsx', index=False, encoding='utf8')
df_05_02_2019.to_excel('02_02_2019.xlsx', index=False, encoding='utf8')
df_05_02_2020.to_excel('02_02_2020.xlsx', index=False, encoding='utf8')

# %%
# 예시용 그래프
df_05_01_2016 = df_05_01[df_05_01['시점'] == 2016]

x = ['소계', '1개월이내', '3개월이내', '6개월이내', '1년이내', '2년이내', '3년이내', '3년초과']

plt.style.use('ggplot')
plt.figure(figsize=(8,4))
plt.plot(x, df_05_01_2016.iloc[0, 2:], marker='o', label='total', linestyle='--')
plt.plot(x, df_05_01_2016.iloc[1, 2:], marker='o', label='heinous crime')
plt.plot(x, df_05_01_2016.iloc[2, 2:], marker='o', label='violent crime')
plt.xlabel('period')
plt.ylabel('num')
plt.title('2016y')
plt.legend(fontsize=10)
plt.show()
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 이종재범만 추출
df_05_02 = df_05.drop(['동종재범', '동종재범.1', '동종재범.2', '동종재범.3', '동종재범.4', '동종재범.5', '동종재범.6', '동종재범.7'], axis=1)
df_05_02
# Out:
#       시점  범죄별(1)    범죄별(2)      합계    이종재범 이종재범.1 이종재범.2 이종재범.3 이종재범.4 이종재범.5  \
# 0     시점  범죄별(1)    범죄별(2)      소계      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내
# 1   2016      합계        소계  889429  611999  10597  19606  24789  93024  66060
# 2   2016     형법범        소계  453763  325614   7251  11699  14286  52323  35859
# 3   2016     형법범  강력범죄(흉악)   16653   14875    352    532    718   2302   1614
# 4   2016     형법범  강력범죄(폭력)  160076  116154   2141   3995   5067  17304  13715
# 5   2017      합계        소계  803710  553243   8992  17592  22913  84288  58904
# 6   2017     형법범        소계  425866  303942   6132  11003  13630  49556  33458
# 7   2017     형법범  강력범죄(흉악)   17216   15027    327    529    743   2408   1689
# 8   2017     형법범  강력범죄(폭력)  148678  106618   1701   3754   4766  16419  12422
# 9   2018      합계        소계  718529  495770   7388  14258  19332  73415  54967
# 10  2018     형법범        소계  409671  288543   5393   9560  12435  45783  32953
# ...

# %%
# 컬럼명 변경 & 필요 열 드랍
df_05_02.drop(['범죄별(1)', '합계'], axis=1, inplace=True)
df_05_02.rename(columns={'범죄별(2)': '범죄별', '이종재범' : '소계', '이종재범.1' : '1개월이내', '이종재범.2':'3개월이내', '이종재범.3':'6개월이내', '이종재범.4':'1년이내', '이종재범.5':'2년이내', '이종재범.6':'3년이내', '이종재범.7':'3년초과'}, inplace=True)
df_05_02
# Out:
#       시점       범죄별      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내    3년초과
# 0     시점    범죄별(2)      소계  1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내    3년초과
# 1   2016        소계  611999  10597  19606  24789  93024  66060  69892  328031
# 2   2016        소계  325614   7251  11699  14286  52323  35859  38216  165980
# 3   2016  강력범죄(흉악)   14875    352    532    718   2302   1614   1691    7666
# 4   2016  강력범죄(폭력)  116154   2141   3995   5067  17304  13715  13803   60129
# 5   2017        소계  553243   8992  17592  22913  84288  58904  62711  297843
# 6   2017        소계  303942   6132  11003  13630  49556  33458  35598  154565
# 7   2017  강력범죄(흉악)   15027    327    529    743   2408   1689   1718    7613
# 8   2017  강력범죄(폭력)  106618   1701   3754   4766  16419  12422  12617   54939
# 9   2018        소계  495770   7388  14258  19332  73415  54967  57020  269390
# 10  2018        소계  288543   5393   9560  12435  45783  32953  34034  148385
# ...

# %%
# 행 드랍드랍
df_05_02.drop([0, 1, 5, 9, 13, 17], inplace=True)
df_05_02
# Out:
#       시점       범죄별      소계 1개월이내  3개월이내  6개월이내   1년이내   2년이내   3년이내    3년초과
# 2   2016        소계  325614  7251  11699  14286  52323  35859  38216  165980
# 3   2016  강력범죄(흉악)   14875   352    532    718   2302   1614   1691    7666
# 4   2016  강력범죄(폭력)  116154  2141   3995   5067  17304  13715  13803   60129
# 6   2017        소계  303942  6132  11003  13630  49556  33458  35598  154565
# 7   2017  강력범죄(흉악)   15027   327    529    743   2408   1689   1718    7613
# 8   2017  강력범죄(폭력)  106618  1701   3754   4766  16419  12422  12617   54939
# 10  2018        소계  288543  5393   9560  12435  45783  32953  34034  148385
# 11  2018  강력범죄(흉악)   13878   249    467    592   2214   1669   1643    7044
# 12  2018  강력범죄(폭력)   97900  1355   2951   4136  14234  11898  11548   51778
# 14  2019        소계  297675  5342   9418  11857  45463  32695  35826  157074
# 15  2019  강력범죄(흉악)   13790   238    460    547   2141   1610   1674    7120
# ...

# %%
# object -> int
df_05_02['시점'] = df_05_02['시점'].astype(str).astype(int)
df_05_02['소계'] = df_05_02['소계'].astype(str).astype(int)
df_05_02['1개월이내'] = df_05_02['1개월이내'].astype(str).astype(int)
df_05_02['3개월이내'] = df_05_02['3개월이내'].astype(str).astype(int)
df_05_02['6개월이내'] = df_05_02['6개월이내'].astype(str).astype(int)
df_05_02['1년이내'] = df_05_02['1년이내'].astype(str).astype(int)
df_05_02['2년이내'] = df_05_02['2년이내'].astype(str).astype(int)
df_05_02['3년이내'] = df_05_02['3년이내'].astype(str).astype(int)
df_05_02['3년초과'] = df_05_02['3년초과'].astype(str).astype(int)



df_05_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 2 to 20
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      15 non-null     int64
#  1   범죄별     15 non-null     object
#  2   소계      15 non-null     int64
#  3   1개월이내   15 non-null     int64
#  4   3개월이내   15 non-null     int64
#  5   6개월이내   15 non-null     int64
#  6   1년이내    15 non-null     int64
#  7   2년이내    15 non-null     int64
#  8   3년이내    15 non-null     int64
#  9   3년초과    15 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 1.3+ KB

# %%
# 같은 년도의 동종재범 & 이종재범 그래프 하나로 나타내기
# 예시용이라 대충..

df_05_01_2016 = df_05_01[df_05_01['시점'] == 2016]
df_05_02_2016 = df_05_02[df_05_02['시점'] == 2016]

x = ['소계', '1개월이내', '3개월이내', '6개월이내', '1년이내', '2년이내', '3년이내', '3년초과']

plt.style.use('ggplot')
plt.figure(figsize=(8,6))
plt.plot(x, df_05_01_2016.iloc[0, 2:], marker='o', color='olive', label='total(same)', linestyle='--')
plt.plot(x, df_05_01_2016.iloc[1, 2:], marker='o', color='olive', label='heinous crime(same)', linestyle='--')
plt.plot(x, df_05_01_2016.iloc[2, 2:], marker='o', color='olive', label='violent crime(same)', linestyle='--')
plt.plot(x, df_05_02_2016.iloc[0, 2:], marker='o', color='lightblue', label='total(diff)')
plt.plot(x, df_05_02_2016.iloc[1, 2:], marker='o', color='lightblue', label='heinous crime(diff)')
plt.plot(x, df_05_02_2016.iloc[2, 2:], marker='o', color='lightblue', label='violent crime(diff)')
plt.xlabel('period')
plt.ylabel('num')
plt.title('2016y')
plt.legend(fontsize=10)
plt.show()
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df_05_01.to_csv('02_01_동종재범_fin.csv', index=False)
df_05_02.to_csv('02_02_이종재범_fin.csv', index=False)

# %%
# 시간대별 범죄 발생
df_06 = pd.read_csv('/Users/dabeen/Desktop/K-DigitalTraining/Project/Machine_Learning/New_Project/발생시간별범죄.csv', encoding='cp949')
df_06
# Out:
#     죄종별(1)       죄종별(2)     2016       2016.1       2016.2       2016.3  \
# 0   죄종별(1)       죄종별(2)        계  00:00~02:59  03:00~05:59  06:00~08:59
# 1        계           소계  1849450       121805       107865       108645
# 2     강력범죄           소계    25765         2978         3068         1962
# 3     강력범죄         살인기수      356           30           32           32
# 4     강력범죄        살인미수등      558           47           38           42
# 5     강력범죄           강도     1149          147          200           78
# 6     강력범죄           강간     5155          695          743          366
# 7     강력범죄         유사강간      583           68           80           39
# 8     강력범죄         강제추행    16054         1771         1737         1282
# 9     강력범죄  기타 강간·강제추행등      408           47           53           17
# 10    강력범죄           방화     1502          173          185          106
# 11    폭력범죄           소계   309394        38007        30550        18553
# ...

# %%
# 컬럼명 재정의
df_06.rename(columns=df_06.iloc[0], inplace=True)
df_06
# Out:
#     죄종별(1)       죄종별(2)        계  00:00~02:59  03:00~05:59  06:00~08:59  \
# 0   죄종별(1)       죄종별(2)        계  00:00~02:59  03:00~05:59  06:00~08:59
# 1        계           소계  1849450       121805       107865       108645
# 2     강력범죄           소계    25765         2978         3068         1962
# 3     강력범죄         살인기수      356           30           32           32
# 4     강력범죄        살인미수등      558           47           38           42
# 5     강력범죄           강도     1149          147          200           78
# 6     강력범죄           강간     5155          695          743          366
# 7     강력범죄         유사강간      583           68           80           39
# 8     강력범죄         강제추행    16054         1771         1737         1282
# 9     강력범죄  기타 강간·강제추행등      408           47           53           17
# 10    강력범죄           방화     1502          173          185          106
# 11    폭력범죄           소계   309394        38007        30550        18553
# ...

# %%
df_06.drop([0], inplace=True)
df_06
# Out:
#    죄종별(1)       죄종별(2)        계 00:00~02:59 03:00~05:59 06:00~08:59  \
# 1       계           소계  1849450      121805      107865      108645
# 2    강력범죄           소계    25765        2978        3068        1962
# 3    강력범죄         살인기수      356          30          32          32
# 4    강력범죄        살인미수등      558          47          38          42
# 5    강력범죄           강도     1149         147         200          78
# 6    강력범죄           강간     5155         695         743         366
# 7    강력범죄         유사강간      583          68          80          39
# 8    강력범죄         강제추행    16054        1771        1737        1282
# 9    강력범죄  기타 강간·강제추행등      408          47          53          17
# 10   강력범죄           방화     1502         173         185         106
# 11   폭력범죄           소계   309394       38007       30550       18553
# 12   폭력범죄           상해    50028        6054        4735        3027
# 13   폭력범죄           폭행   165803       22672       18194        9597
# ...

# %%
# object -> int
df_06['계'] = df_06['계'].astype(str).astype(int)
df_06['00:00~02:59'] = df_06['00:00~02:59'].astype(str).astype(int)
df_06['03:00~05:59'] = df_06['03:00~05:59'].astype(str).astype(int)
df_06['06:00~08:59'] = df_06['06:00~08:59'].astype(str).astype(int)
df_06['09:00~11:59'] = df_06['09:00~11:59'].astype(str).astype(int)
df_06['12:00~14:59'] = df_06['12:00~14:59'].astype(str).astype(int)
df_06['15:00~17:59'] = df_06['15:00~17:59'].astype(str).astype(int)
df_06['18:00~20:59'] = df_06['18:00~20:59'].astype(str).astype(int)
df_06['21:00~23:59'] = df_06['21:00~23:59'].astype(str).astype(int)


df_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 1 to 19
# Data columns (total 52 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   죄종별(1)       19 non-null     object
#  1   죄종별(2)       19 non-null     object
#  2   계            19 non-null     int64
#  3   00:00~02:59  19 non-null     int64
#  4   03:00~05:59  19 non-null     int64
#  5   06:00~08:59  19 non-null     int64
#  6   09:00~11:59  19 non-null     int64
#  7   12:00~14:59  19 non-null     int64
#  8   15:00~17:59  19 non-null     int64
#  9   18:00~20:59  19 non-null     int64
#  10  21:00~23:59  19 non-null     int64
#  11  미상           19 non-null     object
#  12  계            19 non-null     int64
#  13  00:00~02:59  19 non-null     int64
#  14  03:00~05:59  19 non-null     int64
#  15  06:00~08:59  19 non-null     int64
#  16  09:00~11:59  19 non-null     int64
#  17  12:00~14:59  19 non-null     int64
#  18  15:00~17:59  19 non-null     int64
# ...

# %%
# index 정의
df_06.set_index(['죄종별(2)'], inplace=True)
df_06
# Out:
#             죄종별(1)        계  00:00~02:59  03:00~05:59  06:00~08:59  \
# 죄종별(2)
# 소계               계  1849450       121805       107865       108645
# 소계            강력범죄    25765         2978         3068         1962
# 살인기수          강력범죄      356           30           32           32
# 살인미수등         강력범죄      558           47           38           42
# 강도            강력범죄     1149          147          200           78
# 강간            강력범죄     5155          695          743          366
# 유사강간          강력범죄      583           68           80           39
# 강제추행          강력범죄    16054         1771         1737         1282
# 기타 강간·강제추행등   강력범죄      408           47           53           17
# 방화            강력범죄     1502          173          185          106
# 소계            폭력범죄   309394        38007        30550        18553
# 상해            폭력범죄    50028         6054         4735         3027
# 폭행            폭력범죄   165803        22672        18194         9597
# ...

# %%
# 년도별 추출
df_06_2016 = df_06.iloc[:,:11]
df_06_2016
# Out:
#             죄종별(1)        계  00:00~02:59  03:00~05:59  06:00~08:59  \
# 죄종별(2)
# 소계               계  1849450       121805       107865       108645
# 소계            강력범죄    25765         2978         3068         1962
# 살인기수          강력범죄      356           30           32           32
# 살인미수등         강력범죄      558           47           38           42
# 강도            강력범죄     1149          147          200           78
# 강간            강력범죄     5155          695          743          366
# 유사강간          강력범죄      583           68           80           39
# 강제추행          강력범죄    16054         1771         1737         1282
# 기타 강간·강제추행등   강력범죄      408           47           53           17
# 방화            강력범죄     1502          173          185          106
# 소계            폭력범죄   309394        38007        30550        18553
# 상해            폭력범죄    50028         6054         4735         3027
# 폭행            폭력범죄   165803        22672        18194         9597
# ...

# %%
# 년도별 추출(2)
df_06_2017 = df_06.iloc[:, 11:21]
df_06_2017.insert(0, "죄종별(1)",df_06["죄종별(1)"])
df_06_2017
# Out:
#             죄종별(1)        계  00:00~02:59  03:00~05:59  06:00~08:59  \
# 죄종별(2)
# 소계               계  1662341       111172        98922        97823
# 소계            강력범죄    27274         3182         3377         2205
# 살인기수          강력범죄      301           20           28           31
# 살인미수등         강력범죄      524           47           41           44
# 강도            강력범죄      967          132          162           58
# 강간            강력범죄     5223          720          886          383
# 유사강간          강력범죄      636           82          101           58
# 강제추행          강력범죄    17947         1994         1981         1527
# 기타 강간·강제추행등   강력범죄      304           30           38           19
# 방화            강력범죄     1372          157          140           85
# 소계            폭력범죄   293086        35100        29547        17986
# 상해            폭력범죄    44611         5278         4426         2709
# 폭행            폭력범죄   159641        21395        17631         9412
# ...

# %%
# 년도별 추출(3)
df_06_2018 = df_06.iloc[:, 21:31]
df_06_2018.insert(0, "죄종별(1)",df_06["죄종별(1)"])
df_06_2019 = df_06.iloc[:, 31:41]
df_06_2019.insert(0, "죄종별(1)",df_06["죄종별(1)"])
df_06_2020 = df_06.iloc[:, 41:51]
df_06_2020.insert(0, "죄종별(1)",df_06["죄종별(1)"])
df_06_2020
# Out:
#             죄종별(1)        계  00:00~02:59  03:00~05:59  06:00~08:59  \
# 죄종별(2)
# 소계               계  1587866        86398        81043        81052
# 소계            강력범죄    24332         2642         2754         1478
# 살인기수          강력범죄      308           20           30           23
# 살인미수등         강력범죄      416           35           27           40
# 강도            강력범죄      663           80           93           34
# 강간            강력범죄     5313          636          750          358
# 유사강간          강력범죄      823           96          127           58
# 강제추행          강력범죄    15344         1619         1568          882
# 기타 강간·강제추행등   강력범죄      237           24           27           16
# 방화            강력범죄     1228          132          132           67
# 소계            폭력범죄   265768        27024        23076        15870
# 상해            폭력범죄    32904         3514         2951         2016
# 폭행            폭력범죄   139361        15946        13505         8012
# ...

# %%
df_06_2016.to_excel('03_2016.xlsx', index=False, encoding='utf8')
df_06_2017.to_excel('03_2017.xlsx', index=False, encoding='utf8')
df_06_2018.to_excel('03_2018.xlsx', index=False, encoding='utf8')
df_06_2019.to_excel('03_2019.xlsx', index=False, encoding='utf8')
df_06_2020.to_excel('03_2020.xlsx', index=False, encoding='utf8')

# %%
# 강력범죄, 폭력범죄 분리
df_06_2016_01 = df_06_2016[df_06_2016['죄종별(1)'] == '강력범죄']
df_06_2016_02 = df_06_2016[df_06_2016['죄종별(1)'] == '폭력범죄']
df_06_2016_01
# Out:
#             죄종별(1)      계  00:00~02:59  03:00~05:59  06:00~08:59  09:00~11:59  \
# 죄종별(2)
# 소계            강력범죄  25765         2978         3068         1962         1652
# 살인기수          강력범죄    356           30           32           32           36
# 살인미수등         강력범죄    558           47           38           42           53
# 강도            강력범죄   1149          147          200           78           71
# 강간            강력범죄   5155          695          743          366          301
# 유사강간          강력범죄    583           68           80           39           44
# 강제추행          강력범죄  16054         1771         1737         1282          992
# 기타 강간·강제추행등   강력범죄    408           47           53           17           25
# 방화            강력범죄   1502          173          185          106          130
#
#              12:00~14:59  15:00~17:59  18:00~20:59  21:00~23:59    미상
# 죄종별(2)
# 소계                  1808         2252         3039         4360  4646
# ...

# %%
df_06_2016_01.to_excel('03_2016_01.xlsx', index=False, encoding='utf8')
df_06_2016_02.to_excel('03_2016_02.xlsx', index=False, encoding='utf8')

# %%
# 강력범죄, 폭력범죄 분리 & 저장

df_06_2017_01 = df_06_2017[df_06_2017['죄종별(1)'] == '강력범죄']
df_06_2017_02 = df_06_2017[df_06_2017['죄종별(1)'] == '폭력범죄']
df_06_2017_01.to_excel('03_2017_01.xlsx', index=False, encoding='utf8')
df_06_2017_02.to_excel('03_2017_02.xlsx', index=False, encoding='utf8')

df_06_2018_01 = df_06_2018[df_06_2018['죄종별(1)'] == '강력범죄']
df_06_2018_02 = df_06_2018[df_06_2018['죄종별(1)'] == '폭력범죄']
df_06_2018_01.to_excel('03_2018_01.xlsx', index=False, encoding='utf8')
df_06_2018_02.to_excel('03_2018_02.xlsx', index=False, encoding='utf8')

df_06_2019_01 = df_06_2019[df_06_2019['죄종별(1)'] == '강력범죄']
df_06_2019_02 = df_06_2019[df_06_2019['죄종별(1)'] == '폭력범죄']
df_06_2019_01.to_excel('03_2019_01.xlsx', index=False, encoding='utf8')
df_06_2019_02.to_excel('03_2019_02.xlsx', index=False, encoding='utf8')

df_06_2020_01 = df_06_2020[df_06_2020['죄종별(1)'] == '강력범죄']
df_06_2020_02 = df_06_2020[df_06_2020['죄종별(1)'] == '폭력범죄']
df_06_2020_01.to_excel('03_2020_01.xlsx', index=False, encoding='utf8')
df_06_2020_02.to_excel('03_2020_02.xlsx', index=False, encoding='utf8')

# %%
# 왼쪽은 강력범죄, 오른쪽은 폭력범죄
# 그래프


plt.style.use('ggplot')
fig = plt.figure(figsize=[15, 6])
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.plot(df_06_2016_01.index, df_06_2016_01['00:00~02:59'], marker='o', color='olive', label='00:00~02:59')
ax1.plot(df_06_2016_01.index, df_06_2016_01['03:00~05:59'], marker='o', color='olive', label='03:00~05:59')
ax1.plot(df_06_2016_01.index, df_06_2016_01['06:00~08:59'], marker='o', color='olive', label='06:00~08:59')
ax1.plot(df_06_2016_01.index, df_06_2016_01['09:00~11:59'], marker='o', color='olive', label='09:00~11:59')
ax1.plot(df_06_2016_01.index, df_06_2016_01['12:00~14:59'], marker='o', color='olive', label='12:00~14:59')
ax1.plot(df_06_2016_01.index, df_06_2016_01['15:00~17:59'], marker='o', color='olive', label='15:00~17:59')
ax1.plot(df_06_2016_01.index, df_06_2016_01['18:00~20:59'], marker='o', color='olive', label='18:00~20:59')
ax1.plot(df_06_2016_01.index, df_06_2016_01['21:00~23:59'], marker='o', color='olive', label='21:00~23:59')

ax2.plot(df_06_2016_02.index, df_06_2016_02['00:00~02:59'], marker='o', color='lightblue', label='00:00~02:59')
ax2.plot(df_06_2016_02.index, df_06_2016_02['03:00~05:59'], marker='o', color='lightblue', label='03:00~05:59')
ax2.plot(df_06_2016_02.index, df_06_2016_02['06:00~08:59'], marker='o', color='lightblue', label='06:00~08:59')
ax2.plot(df_06_2016_02.index, df_06_2016_02['09:00~11:59'], marker='o', color='lightblue', label='09:00~11:59')
ax2.plot(df_06_2016_02.index, df_06_2016_02['12:00~14:59'], marker='o', color='lightblue', label='12:00~14:59')
ax2.plot(df_06_2016_02.index, df_06_2016_02['15:00~17:59'], marker='o', color='lightblue', label='15:00~17:59')
ax2.plot(df_06_2016_02.index, df_06_2016_02['18:00~20:59'], marker='o', color='lightblue', label='18:00~20:59')
ax2.plot(df_06_2016_02.index, df_06_2016_02['21:00~23:59'], marker='o', color='lightblue', label='21:00~23:59')

ax1.legend(fontsize=10)
ax2.legend(fontsize=10)

# 강력
ax1.set_title('df_06_2016_01', size=12)
# 폭력
ax2.set_title('df_06_2016_02', size=12)

plt.show()
# Out:
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/dabeen/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 모든 저장은 xlsx로 (테스트 결과 csv는 어떤걸로 인코딩하든 맥이랑 윈도우가 호환이 안됐음 ㅠㅠ)
