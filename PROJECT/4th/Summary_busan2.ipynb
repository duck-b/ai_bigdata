# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %%
pd.set_option('display.max_columns', 100)
pd.options.display.float_format = '{:.2f}'.format

# %%
import matplotlib
from matplotlib import font_manager, rc

rc('font', family='AppleGothic')
matplotlib.rcParams['axes.unicode_minus'] = False

plt.style.use('ggplot')

# %%
busan = pd.read_csv('./부산광역시_지표.csv')
busan
# Out:
#     id    구군  면적(km²)  공공체육시설  초등학교 지방세 징수(백만원)  의료기관  저소득층(가구)  저소득층(인구)  \
# 0    1    중구     2.83      17     4     100,363   141       139       280
# 1    2    서구    13.98      74    11      73,444   148       672      1281
# 2    3    동구     9.87      65     7     119,496   172       532      1129
# 3    4   영도구    14.20      52    14      63,242   146       667      1289
# 4    5  부산진구    29.67     225    32     343,404   799      1176      2402
# 5    6   동래구    16.63      36    22     227,601   469       784      1530
# 6    7    남구    26.82      74    21     232,160   355       720      1392
# 7    8    북구    39.37      67    27     130,947   360      1220      2602
# 8    9  해운대구    51.47     117    32     449,970   654      1406      2881
# 9   10   사하구    41.77      59    26     203,760   416      1366      2859
# 10  11   금정구    65.27     118    22     181,128   357       828      1692
# 11  12   강서구   181.49     158    18     462,338    97       252       539
# 12  13   연제구    12.10      33    16     177,833   354       681      1370
# 13  14   수영구    10.21      51    10     159,625   307       498      1009
# 14  15   사상구    36.09     102    21     178,957   242       751      1567
# 15  16   기장군   218.30     200    21     250,288   167       737      1658
#
#         세대수   한국인(남)   한국인(여) 외국인(남) 외국인(여)  출생(명)  사망(명)  혼인(건)  이혼(건)  \
# 0    23,160   20,557   21,353  1,347    815    112    409    163     91
# 1    52,786   52,627   55,602  1,314    807    386    999    391    227
# 2    44,657   43,327   44,838  1,089  1,223    334    848    369    188
# 3    54,859   57,629   59,082  1,177    740    346   1158    366    259
# 4   166,865  173,446  184,434  1,275  1,889   1695   2450   1475    684
# 5   112,136  132,295  138,952    427    826   1291   1538   1058    498
# 6   117,397  134,519  139,961  3,148  3,224   1203   1726   1045    502
# 7   120,273  144,229  146,903  1,220  1,352   1468   1704   1084    538
# 8   168,650  195,960  210,142  2,539  2,652   1948   2335   1471    724
# 9   138,790  160,101  160,903  2,998  1,949   1526   2093   1337    761
# 10  107,024  117,070  121,992  1,938  2,870   1000   1643    815    409
# 11   53,731   66,982   62,584  4,588    894   1449    556    804    287
# 12   90,266  101,253  108,142    401    647   1214   1217    997    391
# 13   81,452   83,565   92,583    784    965    854   1161    814    335
# 14   96,726  110,286  107,808  2,931  2,464   1015   1441    845    493
# 15   69,136   81,571   83,145  1,505    724   1208    982    746    400
#
#      범죄발생  흉악범죄  폭력범죄  CCTV수   가로등수
# 0    5553    93   674    376   1740
# 1    3979    58   466    376   2779
# 2    5899    89   781    649   3654
# 3    3534    54   569    501   3240
# 4   17066   469  2748   1005   6481
# 5    8381   137  1193    687   4350
# 6    8431   138  1046   3171   4486
# 7    8106   126  1342    661   5438
# 8   14386   267  1732    570  11063
# 9    8826   176  1222   1801   6798
# 10   7663   143   952    570   6008
# 11   6820    63   433    597  24978
# 12   8618   143  1158    507   4076
# 13   5504   105   898   1112   3896
# 14   9398   156  1237    378   6434
# 15   5929    65   534   1120  15863

# %%
busan.columns
# Out:
# Index(['id', '구군', '면적(km²)', '공공체육시설', '초등학교', '지방세 징수(백만원)', '의료기관',
#        '저소득층(가구)', '저소득층(인구)', '세대수', '한국인(남)', '한국인(여)', '외국인(남)', '외국인(여)',
#        '출생(명)', '사망(명)', '혼인(건)', '이혼(건)', '범죄발생', '흉악범죄', '폭력범죄', 'CCTV수',
#        '가로등수'],
#       dtype='object')

# %%
busan['지방세 징수(백만원)'] = pd.to_numeric(busan['지방세 징수(백만원)'].str.replace(',', ''))
busan['세대수'] = pd.to_numeric(busan['세대수'].str.replace(',', ''))
busan['한국인(남)'] = pd.to_numeric(busan['한국인(남)'].str.replace(',', ''))
busan['한국인(여)'] = pd.to_numeric(busan['한국인(여)'].str.replace(',', ''))
busan['외국인(남)'] = pd.to_numeric(busan['외국인(남)'].str.replace(',', ''))
busan['외국인(여)'] = pd.to_numeric(busan['외국인(여)'].str.replace(',', ''))

# %%
busan['인구'] = busan['한국인(남)'] + busan['한국인(여)'] + busan['외국인(남)'] + busan['외국인(여)']
busan['인구/CCTV수'] = busan['인구'] / busan['CCTV수']
busan['면적/CCTV수'] = busan['면적(km²)'] / busan['CCTV수']
busan['인구/가로등수'] = busan['인구'] / busan['가로등수']
busan['면적/가로등수'] = busan['면적(km²)'] / busan['가로등수']
busan['인구/면적'] = busan['인구'] / busan['면적(km²)']
busan['외국인/인구'] = (busan['외국인(남)'] + busan['외국인(여)']) / busan['인구']
busan['저소득층/인구'] = busan['저소득층(인구)'] / busan['인구']
busan['저소득층/세대수'] = busan['저소득층(가구)'] / busan['세대수']
busan['여성/인구'] = (busan['한국인(여)'] + busan['외국인(여)']) / busan['인구']
busan['강력범죄'] = busan['흉악범죄'] + busan['폭력범죄']
busan['범죄/인구'] = busan['범죄발생'] / busan['인구']
busan['강력범죄/범죄'] = busan['강력범죄'] / busan['범죄발생']

# %%
busan.columns
# Out:
# Index(['id', '구군', '면적(km²)', '공공체육시설', '초등학교', '지방세 징수(백만원)', '의료기관',
#        '저소득층(가구)', '저소득층(인구)', '세대수', '한국인(남)', '한국인(여)', '외국인(남)', '외국인(여)',
#        '출생(명)', '사망(명)', '혼인(건)', '이혼(건)', '범죄발생', '흉악범죄', '폭력범죄', 'CCTV수',
#        '가로등수', '인구', '인구/CCTV수', '면적/CCTV수', '인구/가로등수', '면적/가로등수', '인구/면적',
#        '외국인/인구', '저소득층/인구', '저소득층/세대수', '여성/인구', '강력범죄', '범죄/인구', '강력범죄/범죄'],
#       dtype='object')

# %%
busan.describe()
# Out:
#          id  면적(km²)  공공체육시설  초등학교  지방세 징수(백만원)   의료기관  저소득층(가구)  저소득층(인구)  \
# count 16.00    16.00   16.00 16.00        16.00  16.00     16.00     16.00
# mean   8.50    48.13   90.50 19.00    209659.75 324.00    776.81   1592.50
# std    4.76    62.00   59.83  8.29    119312.88 195.06    361.39    758.25
# min    1.00     2.83   17.00  4.00     63242.00  97.00    139.00    280.00
# 25%    4.75    13.51   51.75 13.25    128084.25 162.25    633.25   1243.00
# 50%    8.50    28.25   70.50 21.00    180042.50 330.50    728.50   1461.00
# 75%   12.25    44.20  117.25 23.00    236692.00 374.00    915.00   1869.50
# max   16.00   218.30  225.00 32.00    462338.00 799.00   1406.00   2881.00
#
#             세대수    한국인(남)    한국인(여)  외국인(남)  외국인(여)   출생(명)   사망(명)   혼인(건)  \
# count     16.00     16.00     16.00   16.00   16.00   16.00   16.00   16.00
# mean   93619.25 104713.56 108651.50 1792.56 1502.56 1065.56 1391.25  861.25
# std    42991.68  50140.62  53109.71 1148.26  876.41  534.39  589.80  394.36
# min    23160.00  20557.00  21353.00  401.00  647.00  112.00  409.00  163.00
# 25%    54577.00  64643.75  61708.50 1155.00  813.00  737.00  994.75  657.25
# 50%    93496.00 105769.50 107975.00 1330.50 1094.00 1205.50 1329.00  830.00
# 75%   118116.00 136946.50 141696.50 2637.00 2077.75 1453.75 1709.50 1064.50
# max   168650.00 195960.00 210142.00 4588.00 3224.00 1948.00 2450.00 1475.00
#
#        이혼(건)     범죄발생   흉악범죄    폭력범죄   CCTV수     가로등수        인구  인구/CCTV수  \
# count  16.00    16.00  16.00   16.00   16.00    16.00     16.00     16.00
# mean  424.19  8005.81 142.62 1061.56  880.06  6955.25 216660.19    309.23
# std   193.51  3510.69 102.55  577.00  715.43  5914.03 103900.26    181.55
# min    91.00  3534.00  54.00  433.00  376.00  1740.00  44072.00     88.57
# 25%   280.00  5812.50  83.00  647.75  505.50  3835.50 130943.00    157.25
# 50%   404.50  7884.50 131.50  999.00  623.00  4962.00 216966.00    265.13
# 75%   511.00  8670.00 146.25 1225.75 1031.75  6560.25 284065.00    418.27
# max   761.00 17066.00 469.00 2748.00 3171.00 24978.00 411293.00    721.57
#
#        면적/CCTV수  인구/가로등수  면적/가로등수    인구/면적  외국인/인구  저소득층/인구  저소득층/세대수  여성/인구  \
# count     16.00    16.00    16.00    16.00   16.00    16.00     16.00  16.00
# mean       0.07    39.69     0.01  9345.12    0.02     0.01      0.01   0.51
# std        0.08    16.85     0.00  5338.57    0.01     0.00      0.00   0.01
# min        0.01     5.41     0.00   744.11    0.00     0.00      0.00   0.47
# 25%        0.02    32.38     0.00  7143.21    0.01     0.01      0.01   0.50
# 50%        0.03    40.15     0.00  8172.51    0.02     0.01      0.01   0.51
# 75%        0.09    52.22     0.01 13019.78    0.02     0.01      0.01   0.51
# max        0.30    62.64     0.01 17423.80    0.05     0.01      0.01   0.53
#
#          강력범죄  범죄/인구  강력범죄/범죄
# count   16.00  16.00    16.00
# mean  1204.19   0.04     0.15
# std    677.00   0.02     0.03
# min    496.00   0.03     0.07
# 25%    731.00   0.03     0.14
# 50%   1139.50   0.04     0.15
# 75%   1394.25   0.04     0.16
# max   3217.00   0.13     0.19

# %%
def busan_scatter(x_value):
    x_label = x_value
    x = busan[x_label]

    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(111)
    rects = plt.scatter(x, busan['강력범죄/범죄'], color='#5093FF')

    z = np.polyfit(x, busan['강력범죄/범죄'], 1)
    p = np.poly1d(z)

    plt.plot(x, p(x))

    for i, city in enumerate(busan['구군']):
        ax.annotate(city, ( x[i], busan['강력범죄/범죄'][i]))

    corr = round(scipy.stats.spearmanr(x, busan['강력범죄/범죄']).correlation, 2)
    plt.text(max(x),p(max(x)), 'corr: {}'.format(corr), color='#FFFFFF', bbox={'facecolor':'#5093FF','edgecolor':'#5093FF','boxstyle':'round','alpha':0.5})
    plt.ylabel('강력범죄/범죄')
    plt.xlabel(x_label)
    plt.savefig('./images/scatter_{}.png'.format(x_label.replace('/','_')))
    plt.show()

# %%
busan_scatter('공공체육시설')

# %%
busan_scatter('초등학교')

# %%
busan_scatter('의료기관')

# %%
busan_scatter('지방세 징수(백만원)')

# %%
busan_scatter('CCTV수')

# %%
busan_scatter('가로등수')

# %%
busan_scatter('저소득층(가구)')

# %%
busan_scatter('저소득층(인구)')

# %%
busan_scatter('세대수')

# %%
busan_scatter('한국인(남)')

# %%
busan_scatter('한국인(여)')

# %%
busan_scatter('외국인(남)')

# %%
busan_scatter('외국인(여)')

# %%
busan_scatter('출생(명)')

# %%
busan_scatter('사망(명)')

# %%
busan_scatter('혼인(건)')

# %%
busan_scatter('이혼(건)')

# %%
busan_scatter('범죄발생')

# %%
busan_scatter('흉악범죄')

# %%
busan_scatter('폭력범죄')

# %%
busan_scatter('인구')

# %%
busan_scatter('인구/CCTV수')

# %%
busan_scatter('면적/CCTV수')

# %%
busan_scatter('인구/가로등수')

# %%
busan_scatter('면적/가로등수')

# %%
busan_scatter('인구/면적')

# %%
busan_scatter('외국인/인구')

# %%
busan_scatter('저소득층/인구')

# %%
busan_scatter('저소득층/세대수')

# %%
busan_scatter('여성/인구')

# %%
busan_scatter('강력범죄')

# %%
busan_scatter('범죄/인구')

# %%
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111)
plt.pcolor(scipy.stats.spearmanr(busan).correlation)
plt.xticks(np.arange(0.5, len(busan.columns), 1), busan.columns, rotation=90)
plt.yticks(np.arange(0.5, len(busan.columns), 1), busan.columns)
plt.colorbar()
plt.savefig('./images/heatmap.png'.format(x_label.replace('/','_')))
plt.show()

# %%
from statsmodels.formula.api import ols

# %%
busan.columns
# Out:
# Index(['id', '구군', '면적(km²)', '공공체육시설', '초등학교', '지방세 징수(백만원)', '의료기관',
#        '저소득층(가구)', '저소득층(인구)', '세대수', '한국인(남)', '한국인(여)', '외국인(남)', '외국인(여)',
#        '출생(명)', '사망(명)', '혼인(건)', '이혼(건)', '범죄발생', '흉악범죄', '폭력범죄', 'CCTV수',
#        '가로등수', '인구', '인구/CCTV수', '면적/CCTV수', '인구/가로등수', '면적/가로등수', '인구/면적',
#        '외국인/인구', '저소득층/인구', '저소득층/세대수', '여성/인구', '강력범죄', '범죄/인구', '강력범죄/범죄'],
#       dtype='object')

# %%
busan = busan.rename(columns={'면적(km²)': '면적', '지방세 징수(백만원)': '지방세', '저소득층(가구)': '저소득층가구',
                      '저소득층(인구)': '저소득층인구', '출생(명)': '출생', '사망(명)': '사망', '혼인(건)': '혼인', '이혼(건)': '이혼',
                      '인구/CCTV수': '인구CCTV', '면적/CCTV수': '면적CCTV', '인구/가로등수': '인구가로등', '면적/가로등수': '면적가로등', 
                      '인구/면적': '인구면적', '외국인/인구': '외국인인구', '저소득층/인구': '저소득층인구율', '저소득층/세대수': '저소득층세대수',
                      '여성/인구': '여성인구', '강력범죄/범죄':'강력범죄범죄'})

# %%
res = ols('강력범죄범죄 ~ 여성인구 + 외국인인구 + 인구면적 + 면적가로등 + 인구가로등 + 면적CCTV + 인구CCTV + 이혼 + 혼인 + 사망 + 출생 + 저소득층세대수 + 지방세 + 의료기관', data=busan).fit()

# %%
res.summary()
# Out:
# /Users/jaehyeong/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1534: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 강력범죄범죄   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     242.4
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):             0.0503
# Time:                        10:01:47   Log-Likelihood:                 99.056
# No. Observations:                  16   AIC:                            -168.1
# Df Residuals:                       1   BIC:                            -156.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4296      0.109      3.945      0.158      -0.954       1.814
# 여성인구           0.2196      0.215      1.021      0.493      -2.514       2.953
# 외국인인구         -2.5839      0.229    -11.298      0.056      -5.490       0.322
# 인구면적       -6.836e-06   1.25e-06     -5.484      0.115   -2.27e-05       9e-06
# 면적가로등        -13.9746      1.072    -13.032      0.049     -27.599      -0.350
# 인구가로등         -0.0011      0.000     -7.317      0.086      -0.003       0.001
# 면적CCTV        -0.0210      0.076     -0.275      0.829      -0.989       0.947
# 인구CCTV       -8.3e-05   6.81e-06    -12.179      0.052      -0.000    3.59e-06
# 이혼          6.741e-05   3.66e-05      1.841      0.317      -0.000       0.001
# 혼인            -0.0003   2.51e-05    -11.382      0.056      -0.001    3.32e-05
# 사망          5.766e-05   1.41e-05      4.079      0.153      -0.000       0.000
# 출생             0.0002   1.25e-05     12.749      0.050    5.36e-07       0.000
# 저소득층세대수      -14.1924      1.130    -12.560      0.051     -28.550       0.165
# 지방세        -4.753e-07   2.41e-08    -19.710      0.032   -7.82e-07   -1.69e-07
# 의료기관           0.0002   2.28e-05      7.319      0.086      -0.000       0.000
# ==============================================================================
# Omnibus:                        1.041   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.594   Jarque-Bera (JB):                0.843
# Skew:                          -0.294   Prob(JB):                        0.656
# Kurtosis:                       2.042   Cond. No.                     6.71e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.71e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['범죄/인구'], busan['면적/인구'], color='#5093FF', s=busan['CCTV수'], edgecolors="white")

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['범죄/인구'][i], busan['면적/인구'][i]))
    
plt.ylabel('면적/인구')
plt.xlabel('범죄/인구')
plt.show()
