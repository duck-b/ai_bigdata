# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 100)
pd.options.display.float_format = '{:.2f}'.format

# %%
import matplotlib
from matplotlib import font_manager, rc

rc('font', family='AppleGothic')
matplotlib.rcParams['axes.unicode_minus'] = False

plt.style.use('ggplot')

# %%
busan = pd.read_csv('./부산광역시_지표.csv')
busan
# Out:
#     id    군구  면적(km²)  공공체육시설  초등학교 지방세 징수(백만원)  의료기관  저소득층(가구)  저소득층(인구)  \
# 0    1    중구     2.83      17     4     100,363   141       139       280
# 1    2    서구    13.98      74    11      73,444   148       672      1281
# 2    3    동구     9.87      65     7     119,496   172       532      1129
# 3    4   영도구    14.20      52    14      63,242   146       667      1289
# 4    5  부산진구    29.67     225    32     343,404   799      1176      2402
# 5    6   동래구    16.63      36    22     227,601   469       784      1530
# 6    7    남구    26.82      74    21     232,160   355       720      1392
# 7    8    북구    39.37      67    27     130,947   360      1220      2602
# 8    9  해운대구    51.47     117    32     449,970   654      1406      2881
# 9   10   사하구    41.77      59    26     203,760   416      1366      2859
# 10  11   금정구    65.27     118    22     181,128   357       828      1692
# 11  12   강서구   181.49     158    18     462,338    97       252       539
# ...

# %%
busan.columns
# Out:
# Index(['id', '군구', '면적(km²)', '공공체육시설', '초등학교', '지방세 징수(백만원)', '의료기관',
#        '저소득층(가구)', '저소득층(인구)', '세대수', '한국인(남)', '한국인(여)', '외국인(남)', '외국인(여)',
#        '출생(명)', '사망(명)', '혼인(건)', '이혼(건)', '범죄발생', '흉악범죄', '폭력범죄', 'CCTV수'],
#       dtype='object')

# %%
busan['지방세 징수(백만원)'] = pd.to_numeric(busan['지방세 징수(백만원)'].str.replace(',', ''))
busan['세대수'] = pd.to_numeric(busan['세대수'].str.replace(',', ''))
busan['한국인(남)'] = pd.to_numeric(busan['한국인(남)'].str.replace(',', ''))
busan['한국인(여)'] = pd.to_numeric(busan['한국인(여)'].str.replace(',', ''))
busan['외국인(남)'] = pd.to_numeric(busan['외국인(남)'].str.replace(',', ''))
busan['외국인(여)'] = pd.to_numeric(busan['외국인(여)'].str.replace(',', ''))

# %%
busan['인구'] = busan['한국인(남)'] + busan['한국인(여)'] + busan['외국인(남)'] + busan['외국인(여)']
busan['인구/CCTV수'] = busan['인구'] / busan['CCTV수']
busan['면적/CCTV수'] = busan['면적(km²)'] / busan['CCTV수']
busan['면적/인구'] = busan['면적(km²)'] / busan['인구']
busan['외국인/인구'] = (busan['외국인(남)'] + busan['외국인(여)']) / busan['인구']
busan['저소득층/인구'] = busan['저소득층(인구)'] / busan['인구']
busan['저소득층/세대수'] = busan['저소득층(가구)'] / busan['세대수']
busan['여성/인구'] = (busan['한국인(여)'] + busan['외국인(여)']) / busan['세대수']
busan['강력범죄'] = busan['흉악범죄'] + busan['폭력범죄']
busan['범죄/인구'] = busan['범죄발생'] / busan['인구']
busan['강력범죄/범죄'] = busan['강력범죄'] / busan['범죄발생']

# %%
busan.describe()
# Out:
#          id  면적(km²)  공공체육시설  초등학교  지방세 징수(백만원)   의료기관  저소득층(가구)  저소득층(인구)  \
# count 16.00    16.00   16.00 16.00        16.00  16.00     16.00     16.00
# mean   8.50    48.13   90.50 19.00    209659.75 324.00    776.81   1592.50
# std    4.76    62.00   59.83  8.29    119312.88 195.06    361.39    758.25
# min    1.00     2.83   17.00  4.00     63242.00  97.00    139.00    280.00
# 25%    4.75    13.51   51.75 13.25    128084.25 162.25    633.25   1243.00
# 50%    8.50    28.25   70.50 21.00    180042.50 330.50    728.50   1461.00
# 75%   12.25    44.20  117.25 23.00    236692.00 374.00    915.00   1869.50
# max   16.00   218.30  225.00 32.00    462338.00 799.00   1406.00   2881.00
#
#             세대수    한국인(남)    한국인(여)  외국인(남)  외국인(여)   출생(명)   사망(명)   혼인(건)  \
# count     16.00     16.00     16.00   16.00   16.00   16.00   16.00   16.00
# mean   93619.25 104713.56 108651.50 1792.56 1502.56 1065.56 1391.25  861.25
# ...

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
plt.pie(busan['면적(km²)'], labels=busan['군구'], autopct='%.1f%%')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan.공공체육시설, height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+'개', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('공공체육시설')
plt.show()
# Out:
# C:\Users\say_s\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\say_s\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\say_s\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan.초등학교, height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+'개', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('초등학교')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['지방세 징수(백만원)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+'백만원', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('지방세 징수(백만원)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['의료기관'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+'개', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('의료기관')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['저소득층(가구)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+' 가구', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('저소득층(가구)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['저소득층(인구)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+' 명', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('저소득층(인구)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan.세대수, height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('세대수')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['한국인(남)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('한국인(남)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['한국인(여)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('한국인(여)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['외국인(남)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('외국인(남)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['외국인(여)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('외국인(여)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['출생(명)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('출생(명)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['사망(명)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('사망(명)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['혼인(건)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('혼인(건)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['이혼(건)'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('이혼(건)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['범죄발생'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('범죄발생')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['폭력범죄'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('폭력범죄')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan.인구, height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+'명', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('인구(명)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['CCTV수'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),','))+'대', ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('CCTV수')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['강력범죄'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('강력범죄')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.barh(busan.군구, busan['흉악범죄'], height=0.6, color='#5093FF')

for i, rect in enumerate(rects):
    ax.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0, str(format(rect.get_width(),',')), ha='right', va='center', size=8, color='#FFFFFF')

plt.ylabel('구군')
plt.xlabel('흉악범죄')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['면적(km²)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['면적(km²)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('면적(km²)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan.공공체육시설, busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['공공체육시설'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('공공체육시설')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan.초등학교, busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['초등학교'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('초등학교')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['지방세 징수(백만원)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['지방세 징수(백만원)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('지방세 징수(백만원)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['의료기관'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['의료기관'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('의료기관')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['저소득층(가구)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['저소득층(가구)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('저소득층(가구)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['저소득층(인구)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['저소득층(인구)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('저소득층(인구)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['세대수'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['세대수'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('세대수')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['한국인(남)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['한국인(남)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('한국인(남)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['한국인(여)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['한국인(여)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('한국인(여)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['외국인(남)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['외국인(남)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('외국인(남)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['외국인(여)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['외국인(여)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('외국인(여)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['출생(명)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['출생(명)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('출생(명)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['사망(명)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['사망(명)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('사망(명)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['혼인(건)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['혼인(건)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('혼인(건)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['이혼(건)'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['이혼(건)'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('이혼(건)')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['흉악범죄'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['흉악범죄'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('흉악범죄')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['폭력범죄'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['폭력범죄'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('폭력범죄')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['CCTV수'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['CCTV수'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('CCTV수')
plt.show()

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111)
rects = plt.scatter(busan['강력범죄'], busan['범죄발생'], color='#5093FF')

for i, city in enumerate(busan['군구']):
    ax.annotate(city, ( busan['강력범죄'][i], busan['범죄발생'][i]))
    
plt.ylabel('범죄발생')
plt.xlabel('강력범죄')
plt.show()
