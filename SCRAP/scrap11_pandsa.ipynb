# %%
# !pip list
# !pip install -U finance-datareader

# %%
import pandas as pd
import FinanceDataReader as fdr

# %%
df_kospi = fdr.StockListing('KOSPI')

df_kospi.shape
# Out:
# (5166, 10)

# %%
df_kospi.head(2)
# Out:
#    Symbol Market    Name           Sector             Industry ListingDate  \
# 1  095570  KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840  KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
#
#   SettleMonth     Representative                       HomePage Region
# 1         12월                박대현         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시

# %%
df_kospi.tail()
# Out:
#       Symbol Market     Name       Sector        Industry ListingDate  \
# 6824  069260  KOSPI      휴켐스  기타 화학제품 제조업     화합물,화학제품 제조  2002-10-07
# 6828  000540  KOSPI     흥국화재          보험업            손해보험  1974-12-05
# 6829  000547  KOSPI  흥국화재2우B          NaN             NaN         NaT
# 6830  000545  KOSPI    흥국화재우          NaN             NaN         NaT
# 6831  003280  KOSPI     흥아해운       해상 운송업  외항화물운송업(케미컬탱커)  1976-06-29
#
#      SettleMonth Representative                    HomePage Region
# 6824         12월            신진용      http://www.huchems.com  서울특별시
# 6828         12월            권중원  http://www.insurance.co.kr  서울특별시
# 6829         NaN            NaN                         NaN    NaN
# 6830         NaN            NaN                         NaN    NaN
# 6831         12월            이환구      http://www.heung-a.com  서울특별시

# %%
df_kosdaq = fdr.StockListing('KOSDAQ')

df_kosdaq.shape
# Out:
# (1536, 10)

# %%
df_kospi[df_kospi['Name'] == '삼성전자']
# Out:
#       Symbol Market  Name          Sector  \
# 3735  005930  KOSPI  삼성전자  통신 및 방송 장비 제조업
#
#                                                Industry ListingDate  \
# 3735  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#      SettleMonth Representative              HomePage Region
# 3735         12월  김기남, 김현석, 고동진  http://www.sec.co.kr    경기도

# %%
df_kospi[(df_kospi['Name'] == '삼성전자') | (df_kospi['Name'] == '삼성전기')]
# Out:
#       Symbol Market  Name          Sector  \
# 3733  009150  KOSPI  삼성전기        전자부품 제조업
# 3735  005930  KOSPI  삼성전자  통신 및 방송 장비 제조업
#
#                                                Industry ListingDate  \
# 3733  영상,음향,통신장비,모듈,다층인쇄회로기판,적층세라믹콘덴서,고주파필터,전압제어발진기,...  1979-02-27
# 3735  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#      SettleMonth Representative                      HomePage Region
# 3733         12월            경계현  http://www.sem.samsung.co.kr    경기도
# 3735         12월  김기남, 김현석, 고동진          http://www.sec.co.kr    경기도

# %%
df_kospi.columns
# Out:
# Index(['Symbol', 'Market', 'Name', 'Sector', 'Industry', 'ListingDate',
#        'SettleMonth', 'Representative', 'HomePage', 'Region'],
#       dtype='object')

# %%
df_kospi['Region'].value_counts()
# Out:
# 서울특별시      416
# 경기도        151
# 경상남도        42
# 부산광역시       36
# 충청남도        26
# 인천광역시       25
# 대구광역시       21
# 경상북도        20
# 울산광역시       17
# 충청북도        15
# 전라북도        12
# 광주광역시        9
# 전라남도         7
# 제주특별자치도      7
# 대전광역시        7
# 강원도          4
# 세종특별자치시      3
# 싱가포르         1
# 케이맨 제도       1
# Name: Region, dtype: int64

# %%
df_kospi['Sector'].value_counts()
# Out:
# 기타 금융업              60
# 자동차 신품 부품 제조업       45
# 의약품 제조업             40
# 1차 철강 제조업           35
# 기타 화학제품 제조업         30
#                     ..
# 개인 및 가정용품 임대업        1
# 자동차 부품 및 내장품 판매업     1
# 가정용 기기 제조업           1
# 제재 및 목재 가공업          1
# 연료 소매업               1
# Name: Sector, Length: 129, dtype: int64

# %%
df_kospi[(df_kospi['Region'] == '서울특별시') & (df_kospi['Sector'] == '기타 금융업')]
# Out:
#       Symbol Market      Name  Sector  \
# 2     006840  KOSPI     AK홀딩스  기타 금융업
# 48    027410  KOSPI       BGF  기타 금융업
# 54    001040  KOSPI        CJ  기타 금융업
# 81    000210  KOSPI        DL  기타 금융업
# 113   078930  KOSPI        GS  기타 금융업
# 146   012630  KOSPI       HDC  기타 금융업
# 174   096760  KOSPI     JW홀딩스  기타 금융업
# 1058  105560  KOSPI      KB금융  기타 금융업
# 1070  009440  KOSPI   KC그린홀딩스  기타 금융업
# 1304  003550  KOSPI        LG  기타 금융업
# 1317  006260  KOSPI        LS  기타 금융업
# 1320  229640  KOSPI   LS전선아시아  기타 금융업
# 1325  383800  KOSPI     LX홀딩스  기타 금융업
# 1580  034730  KOSPI        SK  기타 금융업
# 1611  036530  KOSPI    SNT홀딩스  기타 금융업
# 2000  072710  KOSPI     농심홀딩스  기타 금융업
# 2048  084690  KOSPI     대상홀딩스  기타 금융업
# 2176  000640  KOSPI  동아쏘시오홀딩스  기타 금융업
# 2308  004990  KOSPI      롯데지주  기타 금융업
# 2391  138040  KOSPI   메리츠금융지주  기타 금융업
# 3743  029780  KOSPI      삼성카드  기타 금융업
# 3754  000070  KOSPI     삼양홀딩스  기타 금융업
# 3802  007540  KOSPI        샘표  기타 금융업
# ...

# %%
df_kospi.dtypes
# Out:
# Symbol                    object
# Market                    object
# Name                      object
# Sector                    object
# Industry                  object
# ListingDate       datetime64[ns]
# SettleMonth               object
# Representative            object
# HomePage                  object
# Region                    object
# dtype: object

# %%
df_kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5166 entries, 1 to 6831
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          5166 non-null   object
#  1   Market          5166 non-null   object
#  2   Name            5166 non-null   object
#  3   Sector          820 non-null    object
#  4   Industry        807 non-null    object
#  5   ListingDate     820 non-null    datetime64[ns]
#  6   SettleMonth     820 non-null    object
#  7   Representative  820 non-null    object
#  8   HomePage        790 non-null    object
#  9   Region          820 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 444.0+ KB

# %%
df_kospi.describe()
# Out:
# <ipython-input-31-c16c804243eb>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_kospi.describe()
#         Symbol Market        Name  Sector Industry          ListingDate  \
# count     5166   5166        5166     820      807                  820
# unique    5166      1        5166     129      764                  652
# top     58G625  KOSPI  KBGE24아모레콜  기타 금융업     지주회사  1976-06-30 00:00:00
# freq         1   5166           1      60       19                    8
# first      NaN    NaN         NaN     NaN      NaN  1956-03-03 00:00:00
# last       NaN    NaN         NaN     NaN      NaN  2021-10-13 00:00:00
#
#        SettleMonth Representative                      HomePage Region
# count          820            820                           790    820
# ...

# %%
df_kospi['ListingDate'].value_counts()
# Out:
# 1976-06-30    8
# 1996-07-03    8
# 1996-12-24    7
# 1976-12-28    6
# 1968-12-27    5
#              ..
# 1976-12-27    1
# 2004-10-27    1
# 2002-07-16    1
# 2021-02-02    1
# 1999-11-26    1
# Name: ListingDate, Length: 652, dtype: int64

# %%
df_kospi[df_kospi['ListingDate'] >= '2000']
# Out:
#       Symbol Market     Name                     Sector  \
# 1     095570  KOSPI   AJ네트웍스            산업용 기계 및 장비 임대업
# 48    027410  KOSPI      BGF                     기타 금융업
# 49    282330  KOSPI   BGF리테일                     종합 소매업
# 50    138930  KOSPI  BNK금융지주                     기타 금융업
# 55    079160  KOSPI   CJ CGV  영화, 비디오물, 방송프로그램 제작 및 배급업
# ...      ...    ...      ...                        ...
# 6802  298000  KOSPI     효성화학                기초 화학물질 제조업
# 6803  093370  KOSPI       후성                기초 화학물질 제조업
# 6805  081660  KOSPI    휠라홀딩스                   생활용품 도매업
# 6816  079980  KOSPI      휴비스                   화학섬유 제조업
# 6824  069260  KOSPI      휴켐스                기타 화학제품 제조업
#
#                                            Industry ListingDate SettleMonth  \
# 1                               렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 48                                             지주회사  2014-05-19         12월
# ...

# %%
df_kospi[df_kospi['Name'].str.contains('CJ')]
# Out:
#     Symbol Market      Name                     Sector  \
# 54  001040  KOSPI        CJ                     기타 금융업
# 55  079160  KOSPI    CJ CGV  영화, 비디오물, 방송프로그램 제작 및 배급업
# 57  00104K  KOSPI  CJ4우(전환)                        NaN
# 58  000120  KOSPI    CJ대한통운                  도로 화물 운송업
# 59  011150  KOSPI     CJ씨푸드                  기타 식품 제조업
# 60  011155  KOSPI   CJ씨푸드1우                        NaN
# 61  001045  KOSPI       CJ우                        NaN
# 62  097950  KOSPI    CJ제일제당                  기타 식품 제조업
# 63  097955  KOSPI  CJ제일제당 우                        NaN
#
#                                              Industry ListingDate SettleMonth  \
# 54                                               지주회사  1973-06-29         12월
# 55                                        영화상영,영화관 운영  2004-12-24         12월
# 57                                                NaN         NaT         NaN
# 58  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02         12월
# ...

# %%
df_kospi.to_csv('output/kospi.csv', index = False)

# %%
ls -al output
# Out:
# total 4224
# drwxr-xr-x@ 20 jaehyeong  staff     640 10 19 10:48 ./
# drwxr-xr-x  17 jaehyeong  staff     544 10 19 10:48 ../
# -rw-r--r--   1 jaehyeong  staff  392684 10 14 14:24 aladin.html
# -rw-r--r--   1 jaehyeong  staff  510568 10 14 14:46 aladin2.html
# -rw-r--r--   1 jaehyeong  staff    4116 10 15 10:33 alexa.csv
# -rw-r--r--   1 jaehyeong  staff     852 10 15 10:42 alexa2.csv
# -rw-r--r--   1 jaehyeong  staff   12283 10 14 17:22 color.csv
# -rw-r--r--   1 jaehyeong  staff   69038 10 18 16:13 flower.jpg
# -rw-r--r--   1 jaehyeong  staff  350352 10 19 10:48 kospi.csv
# -rw-r--r--   1 jaehyeong  staff    9302 10 18 17:13 mountain_0.jpg
# -rw-r--r--   1 jaehyeong  staff    9170 10 18 17:13 mountain_1.jpg
# -rw-r--r--   1 jaehyeong  staff    7015 10 18 17:13 mountain_2.jpg
# -rw-r--r--   1 jaehyeong  staff    7692 10 18 17:13 mountain_3.jpg
# -rw-r--r--   1 jaehyeong  staff   11246 10 18 17:13 mountain_4.jpg
# -rw-r--r--   1 jaehyeong  staff   14424 10 15 15:53 movieKid.csv
# ...

# %%
df_kospi[df_kospi['Name'].str.contains('CJ')].to_csv('output/cj.csv', index = False)

# %%
ls -al output
# Out:
# total 4232
# drwxr-xr-x@ 21 jaehyeong  staff     672 10 19 10:49 ./
# drwxr-xr-x  17 jaehyeong  staff     544 10 19 10:48 ../
# -rw-r--r--   1 jaehyeong  staff  392684 10 14 14:24 aladin.html
# -rw-r--r--   1 jaehyeong  staff  510568 10 14 14:46 aladin2.html
# -rw-r--r--   1 jaehyeong  staff    4116 10 15 10:33 alexa.csv
# -rw-r--r--   1 jaehyeong  staff     852 10 15 10:42 alexa2.csv
# -rw-r--r--   1 jaehyeong  staff    1272 10 19 10:49 cj.csv
# -rw-r--r--   1 jaehyeong  staff   12283 10 14 17:22 color.csv
# -rw-r--r--   1 jaehyeong  staff   69038 10 18 16:13 flower.jpg
# -rw-r--r--   1 jaehyeong  staff  350352 10 19 10:48 kospi.csv
# -rw-r--r--   1 jaehyeong  staff    9302 10 18 17:13 mountain_0.jpg
# -rw-r--r--   1 jaehyeong  staff    9170 10 18 17:13 mountain_1.jpg
# -rw-r--r--   1 jaehyeong  staff    7015 10 18 17:13 mountain_2.jpg
# -rw-r--r--   1 jaehyeong  staff    7692 10 18 17:13 mountain_3.jpg
# -rw-r--r--   1 jaehyeong  staff   11246 10 18 17:13 mountain_4.jpg
# ...

# %%
df_cj = fdr.DataReader('011150', '2017-01-01', '2017-12-31')
df_cj
# Out:
#             Open  High   Low  Close   Volume    Change
# Date
# 2017-01-02  3560  3890  3555   3665  4259573  0.056196
# 2017-01-03  3690  3770  3645   3700  1191015  0.009550
# 2017-01-04  3720  3765  3605   3605   731163 -0.025676
# 2017-01-05  3625  3685  3625   3625   501992  0.005548
# 2017-01-06  3625  3650  3570   3605   364494 -0.005517
# ...          ...   ...   ...    ...      ...       ...
# 2017-12-21  2795  2810  2775   2780    41725 -0.005367
# 2017-12-22  2780  2795  2750   2775    45559 -0.001799
# 2017-12-26  2775  2850  2775   2835    42928  0.021622
# 2017-12-27  2850  2855  2800   2840    34479  0.001764
# 2017-12-28  2850  2875  2825   2875    55258  0.012324
#
# [243 rows x 6 columns]

# %%
# !pip install matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['axes.grid'] = True

# %%
# %%html
# <style>
#     talbe { display: inline-block; }
#     .rendered_tml td, .rendered_html th { text-align: left; }
# </style>
# Out:
# <style>
#     talbe { display: inline-block; }
#     .rendered_tml td, .rendered_html th { text-align: left; }
# </style>

# %%
df_cj['Low'].plot()
df_cj['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_cj['Low'].plot()
df_cj['High'].plot()
plt.savefig('output/cj_graph.png')

# %%
ls -al output
# Out:
# total 4312
# drwxr-xr-x@ 22 jaehyeong  staff     704 10 19 11:47 ./
# drwxr-xr-x  17 jaehyeong  staff     544 10 19 11:38 ../
# -rw-r--r--   1 jaehyeong  staff  392684 10 14 14:24 aladin.html
# -rw-r--r--   1 jaehyeong  staff  510568 10 14 14:46 aladin2.html
# -rw-r--r--   1 jaehyeong  staff    4116 10 15 10:33 alexa.csv
# -rw-r--r--   1 jaehyeong  staff     852 10 15 10:42 alexa2.csv
# -rw-r--r--   1 jaehyeong  staff    1272 10 19 10:49 cj.csv
# -rw-r--r--   1 jaehyeong  staff   38961 10 19 11:47 cj_graph.png
# -rw-r--r--   1 jaehyeong  staff   12283 10 14 17:22 color.csv
# -rw-r--r--   1 jaehyeong  staff   69038 10 18 16:13 flower.jpg
# -rw-r--r--   1 jaehyeong  staff  350352 10 19 10:48 kospi.csv
# -rw-r--r--   1 jaehyeong  staff    9302 10 18 17:13 mountain_0.jpg
# -rw-r--r--   1 jaehyeong  staff    9170 10 18 17:13 mountain_1.jpg
# -rw-r--r--   1 jaehyeong  staff    7015 10 18 17:13 mountain_2.jpg
# -rw-r--r--   1 jaehyeong  staff    7692 10 18 17:13 mountain_3.jpg
# ...
